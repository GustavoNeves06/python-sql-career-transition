# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoNeves06/python-sql-career-transition/blob/main/Python_3_Mundo1_Prof_Gustavo_Guanabara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Teste 1: Nome, idade e peso

nome = input('Qual é o seu nome?')
idade = input('Qual é a sua idade?')
peso = input('Qual é o seu peso?')
print(nome, idade, peso)
# Out:
# Qual é o seu nome?Gugu
# Qual é a sua idade?28
# Qual é o seu peso?130
# Gugu 28 130

# %%
# Desafio 1 - Aula 4

nome = input("Nome?")
print("Prazer em te conhecer,",nome,"!")
# Out:
# Nome?Gugu
# Prazer em te conhecer, Gugu !

# %%
# Desafio 2 - Aula 4

dia = input('Dia?')
mes = input('Mês?')
ano = input('Ano?')

print('Você nasceu no dia',dia,'de',mes,'de',ano,'. Correto?')
# Out:
# Dia?06
# Mês?Dezembro
# Ano?1997
# Você nasceu no dia 06 de Dezembro de 1997 . Correto?

# %%
# Desafio 3 - Aula 4

numero1 = int(input('Primeiro Número? '))
numero2 = int(input('Segundo Número? '))

print('A some é',numero1 + numero2)
# Out:
# Primeiro Número? 67
# Segundo Número? 81
# A some é 148
